# %% [markdown]
# #  Errors and Exceptions¶

# %% [markdown]
#  There are (at least) two distinguishable kinds of errors: `syntax` errors and `exceptions`.

# %% [markdown]
# # Syntax Errors
#
# Syntax errors, also known as parsing errors, are perhaps the most common kind of complaint you get while you are still learning Python
#
# Syntax errors occur when the parser detects an incorrect statement.
#
# OR
#
# A Syntax Error occurs when Python cannot understand your code because it breaks the rules (syntax) of the Python language.
# The program does not start running until the syntax error is fixed.

# %% [markdown]
# # Missing Colon

# %%
while True print('Hello world')

# %% [markdown]
# # Missing Closing Parenthesis

# %%
print("Hello"

# %% [markdown]
# # Incorrect Indentation

# %%
if True:
print("Hello")

# %% [markdown]
# # Exceptions (Runtime Errors)
#
# Even if a statement or expression is syntactically correct, it may cause an error when an attempt is made to execute it. Errors detected during execution are called exceptions and are not unconditionally fatal
#
# An exception is an error that occurs while the program is running.
#
# Unlike syntax errors, the program starts successfully but stops when it encounters the error.

# %% [markdown]
# # ZeroDivisionError
#
# Occurs when dividing by zero.

# %%
number = 10 / 0

# %% [markdown]
# # NameError
#
# Occurs when using a variable that does not exist.

# %%
print(age)

# %% [markdown]
# # TypeError
#
# Occurs when using incompatible data types.

# %%
age = 20

print("Age: " + age)

# %% [markdown]
# # ValueError
#
# Occurs when the data type is correct but the value is invalid.

# %%
age = int("hello")

# %% [markdown]
# # IndexError
#
# Occurs when accessing an index that does not exist.

# %%
numbers = [10, 20, 30]

print(numbers[5])

# %% [markdown]
# # KeyError
#
# Occurs when a dictionary key does not exist.

# %%
student = {
    "name": "John"
}

print(student["age"])

# %% [markdown]
# # AttributeError
#
# Occurs when an object does not have the requested method or attribute.

# %%
numbers = [1, 2, 3]

numbers.upper()

# %% [markdown]
# # FileNotFoundError
#
# Occurs when opening a file that does not exist.

# %%
file = open("students.txt")

# %% [markdown]
# # ModuleNotFoundError
#
# Occurs when importing a module that is not installed.

# %%
import mymodule

# %% [markdown]
# # Handling Exceptions
#
# It is possible to write programs that handle selected exceptions.

# %% [markdown]
# 1. First, the try clause (the statement(s) between the try and except keywords) is executed.
#
# 2. If no exception occurs, the except clause is skipped and execution of the try statement is finished.
#
# 3. If an exception occurs during execution of the try clause, the rest of the clause is skipped. Then, if its type matches the exception named after the except keyword, the except clause is executed, and then execution continues after the try/except block.
#
# 4. If an exception occurs which does not match the exception named in the except clause, it is passed on to outer try statements; if no handler is found, it is an unhandled exception and execution stops with an error message.

# %%
try:
    number = int(input("Enter a number: "))
    print(100 / number)

except ValueError:
    print("Please enter a valid number.")

except ZeroDivisionError:
    print("Division by zero is not allowed.")

# %% [markdown]
# # Catching a Specific Exception

# %%
try:
    number = 10 / 0
except:
    print("An error occurred.")

# %% [markdown]
# # Accessing the Error Message

# %%
try:
    number = 10 / 0
except ZeroDivisionError:
    print("You cannot divide by zero.")

# %% [markdown]
# # Handling Multiple Exceptions

# %%
try:
    age = int("hello")
except ValueError as error:
    print(error)

# %% [markdown]
# # The else Block
#
# The else block runs only if no exception occurs.

# %%
try:
    number = int(input("Enter a number: "))
    print(100 / number)

except ValueError:
    print("Please enter a valid number.")

except ZeroDivisionError:
    print("Division by zero is not allowed.")

# %% [markdown]
# # The finally Block
#
# The finally block always executes, whether an exception occurs or not.

# %%
try:
    file = open("data.txt")
except FileNotFoundError:
    print("File not found.")
finally:
    print("Program finished.")

# %% [markdown]
# # Raising Exceptions
#
# You can intentionally create an exception using raise.

# %%
age = -5

if age < 0:
    raise ValueError("Age cannot be negative.")

# %% [markdown]
# # Complete Example

# %%
try:
    first = int(input("First Number: "))
    second = int(input("Second Number: "))

    result = first / second

except ValueError:
    print("Please enter numbers only.")

except ZeroDivisionError:
    print("Cannot divide by zero.")

else:
    print("Answer:", result)

finally:
    print("Thank you for using the calculator.")
